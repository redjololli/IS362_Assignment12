# %% [markdown]
# #### IS362 Assignment 12
# ##### Redjol Olli

# %% [markdown]
# ## Web APIs
# - The New York Times web site provides a rich set of APIs, as described here:  http://developer.nytimes.com/docsYou’ll need to start by signing up for an API key.Your task is to choose one of the New York Times APIs, construct an interface in Python to read in the JSON data, and transform it into a pandas DataFrame.

# %%
import pandas as pd
import json
import urllib.request
from pandas.io.json import json_normalize
import requests

# %% [markdown]
# Created a developer account at http://developer.nytimes.com

# %%
api_key = '3O9IiYV5wGKoGoH6Q6oK0Mm00gYM05t6'
url = "https://api.nytimes.com/svc/books/v3/lists/names.json?"
string = url+'&api-key='+api_key

response = str(urllib.request.urlopen(string).read(), 'utf-8')

# %% [markdown]
# - Best seller books from API to database.

# %%
bestsellers_books = pd.read_json(response)
bestsellers_books
# Out:
#    status                                          copyright  num_results  \
# 0      OK  Copyright (c) 2020 The New York Times Company....           59
# 1      OK  Copyright (c) 2020 The New York Times Company....           59
# 2      OK  Copyright (c) 2020 The New York Times Company....           59
# 3      OK  Copyright (c) 2020 The New York Times Company....           59
# 4      OK  Copyright (c) 2020 The New York Times Company....           59
# 5      OK  Copyright (c) 2020 The New York Times Company....           59
# 6      OK  Copyright (c) 2020 The New York Times Company....           59
# 7      OK  Copyright (c) 2020 The New York Times Company....           59
# 8      OK  Copyright (c) 2020 The New York Times Company....           59
# 9      OK  Copyright (c) 2020 The New York Times Company....           59
# 10     OK  Copyright (c) 2020 The New York Times Company....           59
# 11     OK  Copyright (c) 2020 The New York Times Company....           59
# ...

# %% [markdown]
# - Using JSON to tidy up the data and make dataset more readable

# %%
api_data = json.loads(response)
pd.json_normalize(api_data['results'])
best_sellers.sort_values(by = ["newest_published_date"], ascending=False)
# Out:
#                                list_name  \
# 0      Combined Print and E-Book Fiction
# 20      Childrens Middle Grade Hardcover
# 24                          Series Books
# 27                 Young Adult Hardcover
# 1   Combined Print and E-Book Nonfiction
# 11       Advice How-To and Miscellaneous
# 23                         Picture Books
# 6                   Paperback Nonfiction
# 4                Trade Fiction Paperback
# 3                   Hardcover Nonfiction
# 2                      Hardcover Fiction
# 48                   Mass Market Monthly
# 32                        Business Books
# 31                      Audio Nonfiction
# 49        Middle Grade Paperback Monthly
# 30                         Audio Fiction
# 42               Graphic Books and Manga
# 58         Young Adult Paperback Monthly
# 56                                Sports
# 55                               Science
# 13               Paperback Graphic Books
# 14                                 Manga
# ...
